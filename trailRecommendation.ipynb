# %% [markdown]
# # Regional Base Ranking Algorithm
#
# The recommendation is rank trails based on 2 components: region and ratings.
#
# If the hiking trail is within user's location region, then those trails will be moved to the top of the list.
#
# Then, the algorithm will then check out the regions that are next to the user's region, which the regions will be sorted based on their average rating.
#
# - Note: the average rating is the calculated by the sum of all the trail's rating over the total number of trails based on their region.

# %%
# Import everything that we need
from dataset import dataSet # Access the sample dataSet
from random import randint

# %% [markdown]
# # Create our Graph
#
# In order to get the neighbour regions from the user's region, we'll first have to create a graph.
#
# This is the map of BC
#
# - Look closely of how each region are connected to each other.
#
# ![mapOfBC](imgSrc/MapBC.png)
#
# Then, we'll create the graph based on the map, so we can now see the neighbour of each regions.
#
# ![graphNeighbour](imgSrc/GraphNeighbourRegion.png)

# %%
# Declare the graph
regionGraph = {
    "Pemberton": ["Whistler"],
    "Whistler": ["Pemberton", "Howe Sound"],
    "Howe Sound": ["Whistler", "Sunshine Coast", "The North Shore"],
    "Sunshine Coast": ["Howe Sound"],
    "The North Shore": ["Howe Sound", "Tri Cities", "Vancouver City"],
    "Vancouver City": ["The North Shore", "Surrey and Langley", "Tsawwassen and Delta", "Tri Cities"],
    "Fraser Valley East": ["Ridge Meadows", "Surrey and Langley", "Manning Provincial Park"],
    "Tri Cities": ["The North Shore", "Surrey and Langley", "Ridge Meadows", "Vancouver City"],
    "Tsawwassen and Delta": ["Vancouver City", "Surrey and Langley"],
    "Surrey and Langley": ["Tri Cities", "Vancouver City", "Tsawwassen and Delta", "Fraser Valley East", "Ridge Meadows"],
    "Ridge Meadows": ["Tri Cities", "Surrey and Langley", "Fraser Valley East"],
    "Manning Provincial Park": ["Fraser Valley East"]
}

# %% [markdown]
# # Helper function
#
# * Create function that will get average rate of the region
#     - **Note:** the average rating is the calculated by the sum of all the trail's rating over the total number of trails based on their region.
#
# * Create function that will sort neighbours based on their average ratings
#     - Using bubble sort to sort neighbour regions based on their average rattings.
#
# * Create function that will sort those hiking trails based on their ratings
#     - Applying quicksort to sort those trails in descending order (ratings)

# %%
# Get average rate of the region
def getAvgRate(region:str):
    totalTrail = 0
    totalRate = 0
    for trail in dataSet:
        if (trail['region'] == region):
            totalRate += trail['rate']
            totalTrail += 1
    
    return round(totalRate / totalTrail, 2)


# Sort neighbours based on their average ratings
def sortNeighbours(arr:list):
    n = len(arr) 
    if n == 1:
        return arr
    else:
        for i in range(n):
            for j in range(n-i-1):
                if (getAvgRate(arr[j]) < getAvgRate(arr[j+1])):
                    tmp = arr[j]
                    arr[j] = arr[j+1]
                    arr[j+1] = tmp
    return arr


# Get list of trails based on their region
def getRegionList(region: str):
    res = []
    for trail in dataSet:
        if (trail["region"] == region):
            res.append(trail)
    return res


# Get list of trails based on their region in decending order (based on their ratings)
def sortRegionList(dataSet: list):
    if (len(dataSet) <= 1):
        return dataSet

    smaller = []
    equal = []
    larger = []
    pivot = dataSet[randint(0, len(dataSet)-1)]["rate"]

    for trail in dataSet:
        if (trail["rate"] < pivot):
            smaller.append(trail)
        elif (trail["rate"] == pivot):
            equal.append(trail)
        else:
            larger.append(trail)
    
    larger = sortRegionList(larger)
    smaller = sortRegionList(smaller)

    return larger + equal + smaller

# %% [markdown]
# # The Algorithm
#
# - First put those trails that are within user's region first
#
# - Then add the other trails from the neighbour regions (based on the region's average ratings)
#
# - Then add the rest in the end

# %%
# The Trail recommendation algorithm
def trailRecommendation(region: str):
    res = []
    tmpRegions = []

    # Add the user's region
    currRegionArr = sortRegionList(getRegionList(region))
    res += currRegionArr
    tmpRegions.append(region)
    neighbourRegions = sortNeighbours(regionGraph[region])

    # Adding neignbour regions
    for region in neighbourRegions:
        tmpRegions.append(region)
        res += sortRegionList(getRegionList(region))

    # Add left over regions
    for region in regionGraph:
        if (region not in tmpRegions):
            tmpRegions.append(region)
            res += sortRegionList(getRegionList(region))

    return res

# %%
# Test out the function
def printJSON(jArr):
    for i in jArr:
        print(f"id: {i['id']},\nregion: {i['region']},\nTrail Title: {i['trailTitle']},\nDifficulty: {i['difficulty']},\nTime: {i['time']},\nRating: {i['rate']},\nTrip Time: {i['tripTime']},\nElevation Gain: {i['elevationGain']},\nSeason: {i['season']},\nCamping: {i['camping']},\nPublic Transit: {i['publicTransit']},\nDog Friendly: {i['dogFriendly']}\n\n")
printJSON(trailRecommendation('Vancouver City'))
# Out:
# id: 37a8ccec053211ec9f58cf7d0294de9c,
# region: Vancouver City,
# Trail Title: Deep lake,
# Difficulty: Easy,
# Time: 1,
# Rating: 4.6,
# Trip Time: 5,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4b4e4738052611ec9f58cf7d0294de9c,
# region: Vancouver City,
# Trail Title: Burnaby Mountain,
# Difficulty: Easy,
# Time: 3,
# Rating: 3.83,
# Trip Time: 8,
# Elevation Gain: 300,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: fbda5a40057311ec9f58cf7d0294de9c,
# region: Vancouver City,
# Trail Title: Foreshore Trail,
# Difficulty: Easy,
# Time: 3,
# Rating: 3.7,
# Trip Time: 5,
# Elevation Gain: 40,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: 4b478394052611ec9f58cf7d0294de9c,
# region: Vancouver City,
# Trail Title: Burnaby Lake,
# Difficulty: Easy,
# Time: 2,
# Rating: 3.27,
# Trip Time: 10,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 3730fb9a053211ec9f58cf7d0294de9c,
# region: Vancouver City,
# Trail Title: Colony Farm Regional Park,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 3,
# Trip Time: 8,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4a86bf10052611ec9f58cf7d0294de9c,
# region: Tsawwassen and Delta,
# Trail Title: Boundary Bay Regional Park,
# Difficulty: Easy,
# Time: 2,
# Rating: 4.14,
# Trip Time: 5,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4b5c1c46052611ec9f58cf7d0294de9c,
# region: Tsawwassen and Delta,
# Trail Title: Burns Bog Delta Nature Reserve,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 3.92,
# Trip Time: 3,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4b2744da052611ec9f58cf7d0294de9c,
# region: Tsawwassen and Delta,
# Trail Title: Brunswick Point,
# Difficulty: Easy,
# Time: 2,
# Rating: 3.7,
# Trip Time: 8,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 379651c0053211ec9f58cf7d0294de9c,
# region: Tsawwassen and Delta,
# Trail Title: Deas Island Regional Park,
# Difficulty: Easy,
# Time: 2,
# Rating: 3.45,
# Trip Time: 5,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 374ed778053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Crown Mountain,
# Difficulty: Difficult,
# Time: 7,
# Rating: 4.69,
# Trip Time: 10,
# Elevation Gain: 385,
# Season: July-October,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: fba157e0057311ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Eagle Bluffs,
# Difficulty: Intermediate,
# Time: 4,
# Rating: 4.37,
# Trip Time: 8,
# Elevation Gain: 350,
# Season: July-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fc2d9bec057311ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Grouse Grind,
# Difficulty: Difficult,
# Time: 1.75,
# Rating: 4.22,
# Trip Time: 3,
# Elevation Gain: 853,
# Season: June-September,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: fc169366057311ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Goat Mountain,
# Difficulty: Intermediate,
# Time: 4,
# Rating: 4.14,
# Trip Time: 8,
# Elevation Gain: 300,
# Season: July-October,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: 4b132c70052611ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Brothers Creek Loop,
# Difficulty: Intermediate,
# Time: 4,
# Rating: 4.11,
# Trip Time: 7,
# Elevation Gain: 350,
# Season: April-November,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4a5ef4c6052611ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Big Cedar and Kennedy Falls Trail,
# Difficulty: Intermediate,
# Time: 5,
# Rating: 4.07,
# Trip Time: 10,
# Elevation Gain: 150,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 36ea330e053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Capilano Pacific Trail,
# Difficulty: Easy,
# Time: 4,
# Rating: 4.06,
# Trip Time: 15,
# Elevation Gain: 236,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: fbb28038057311ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Eagle Bluffs via Horseshoe Bay,
# Difficulty: Difficult,
# Time: 7.5,
# Rating: 4,
# Trip Time: 12,
# Elevation Gain: 975,
# Season: June-October,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4a3db18a052611ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: BCMC Trail,
# Difficulty: Difficult,
# Time: 1.5,
# Rating: 3.86,
# Trip Time: 3,
# Elevation Gain: 853,
# Season: June-September,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: a8a123e0053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Dog Mountain,
# Difficulty: Easy,
# Time: 2,
# Rating: 3.75,
# Trip Time: 5,
# Elevation Gain: 152,
# Season: June-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 3757e4c6053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Cypress Falls,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 3.65,
# Trip Time: 3,
# Elevation Gain: 130,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 36e40b50053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Capilano Canyon,
# Difficulty: Easy,
# Time: 1,
# Rating: 3.6,
# Trip Time: 3,
# Elevation Gain: 100,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 3721d426053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Coliseum Mountain,
# Difficulty: Difficult,
# Time: 10,
# Rating: 3.4,
# Trip Time: 24,
# Elevation Gain: 1245,
# Season: July-September,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: fc293700057311ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Goldie Lake,
# Difficulty: Easy,
# Time: 2,
# Rating: 3.25,
# Trip Time: 3,
# Elevation Gain: 100,
# Season: June-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4a239f70052611ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Baden Powell Deep Cove to Lynn Canyon,
# Difficulty: Intermediate,
# Time: 5,
# Rating: 3.1,
# Trip Time: 12,
# Elevation Gain: 420,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4a311aba052611ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Baden Powell Lynn Canyon to Grouse,
# Difficulty: Intermediate,
# Time: 5,
# Rating: 3.07,
# Trip Time: 10,
# Elevation Gain: 200,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4aa9896e052611ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Bowen Lookout,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 3.07,
# Trip Time: 4,
# Elevation Gain: 110,
# Season: July-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbc8427e057311ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Fisherman's Trail,
# Difficulty: Easy,
# Time: 5,
# Rating: 3,
# Trip Time: 12,
# Elevation Gain: 115,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: 3783b538053211ec9f58cf7d0294de9c,
# region: The North Shore,
# Trail Title: Dam Mountain,
# Difficulty: Easy,
# Time: 2,
# Rating: 2.75,
# Trip Time: 5,
# Elevation Gain: 260,
# Season: July-September,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: 4a5242a8052611ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Bert Flinn Park,
# Difficulty: Easy,
# Time: 1,
# Rating: 4.67,
# Trip Time: 3,
# Elevation Gain: 40,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 49db77a4052611ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Admiralty Point,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 4.5,
# Trip Time: 5,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 37570d08053211ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Crystal Falls,
# Difficulty: Easy,
# Time: 2,
# Rating: 4.37,
# Trip Time: 7,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: a894cc30053211ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Dilly Dally Loop,
# Difficulty: Difficult,
# Time: 12,
# Rating: 4.24,
# Trip Time: 25,
# Elevation Gain: 1142,
# Season: July-October,
# Camping: False,
# Public Transit: True,
# Dog Friendly: False
#
#
# id: 4b282a4e052611ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Buntzen Lake,
# Difficulty: Easy,
# Time: 3.5,
# Rating: 3.78,
# Trip Time: 10,
# Elevation Gain: 110,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 3741060c053211ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Coquitlam Crunch,
# Difficulty: Intermediate,
# Time: 1.5,
# Rating: 3.67,
# Trip Time: 5,
# Elevation Gain: 244,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 4a44e78e052611ec9f58cf7d0294de9c,
# region: Tri Cities,
# Trail Title: Belcarra Bluffs,
# Difficulty: Intermediate,
# Time: 3,
# Rating: 0,
# Trip Time: 6,
# Elevation Gain: 240,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 49ecf2a4052611ec9f58cf7d0294de9c,
# region: Surrey and Langley,
# Trail Title: Aldergrove Regional Park,
# Difficulty: Easy,
# Time: 2,
# Rating: 4.44,
# Trip Time: 5,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 369346c0053211ec9f58cf7d0294de9c,
# region: Surrey and Langley,
# Trail Title: Campbell Valley Regional Park,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 3.95,
# Trip Time: 4,
# Elevation Gain: 152,
# Season: year-round,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: a8936f84053211ec9f58cf7d0294de9c,
# region: Surrey and Langley,
# Trail Title: Derby Reach Regional Park,
# Difficulty: Easy,
# Time: 2.5,
# Rating: 3,
# Trip Time: 8,
# Elevation Gain: 152,
# Season: year-round,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbe16db2057311ec9f58cf7d0294de9c,
# region: Surrey and Langley,
# Trail Title: Fort to Fort Trail,
# Difficulty: Easy,
# Time: 2.5,
# Rating: 0,
# Trip Time: 8,
# Elevation Gain: 152,
# Season: year-round,
# Camping: True,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: 373bb378053211ec9f58cf7d0294de9c,
# region: Pemberton,
# Trail Title: Cool Creek Canyon,
# Difficulty: Intermediate,
# Time: 2,
# Rating: 4.5,
# Trip Time: 3,
# Elevation Gain: 300,
# Season: April-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4a65bcf2052611ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Black Tusk,
# Difficulty: Difficult,
# Time: 11,
# Rating: 4.79,
# Trip Time: 29,
# Elevation Gain: 1740,
# Season: July-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 37459636053211ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Crater Rim Trail,
# Difficulty: Intermediate,
# Time: 2,
# Rating: 4.75,
# Trip Time: 5,
# Elevation Gain: 230,
# Season: May-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fc14cfc2057311ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Garibaldi Lake,
# Difficulty: Intermediate,
# Time: 6,
# Rating: 4.52,
# Trip Time: 18,
# Elevation Gain: 820,
# Season: July-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 4ac9b1b2052611ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Brandywine Falls,
# Difficulty: Easy,
# Time: 0.5,
# Rating: 4.38,
# Trip Time: 1,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 36fbc77c053211ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Cheakamus Lake,
# Difficulty: Easy,
# Time: 5,
# Rating: 4.16,
# Trip Time: 16,
# Elevation Gain: 152,
# Season: May-November,
# Camping: True,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 4ad0a576052611ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Brandywine Meadows,
# Difficulty: Difficult,
# Time: 3.5,
# Rating: 4.15,
# Trip Time: 6,
# Elevation Gain: 550,
# Season: July-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4a221a10052611ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Ascent Trail,
# Difficulty: Difficult,
# Time: 3.5,
# Rating: 4,
# Trip Time: 6,
# Elevation Gain: 1150,
# Season: July-September,
# Camping: False,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 4a6c7a60052611ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Blackcomb Meadows,
# Difficulty: Intermediate,
# Time: 3,
# Rating: 4,
# Trip Time: 8,
# Elevation Gain: 200,
# Season: July-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 3731fd42053211ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Conflict Lake,
# Difficulty: Intermediate,
# Time: 5,
# Rating: 3.75,
# Trip Time: 12,
# Elevation Gain: 180,
# Season: June-September,
# Camping: False,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 26c10740051f11ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Ancient Cedars Trail,
# Difficulty: Intermediate,
# Time: 2,
# Rating: 3.07,
# Trip Time: 5,
# Elevation Gain: 175,
# Season: June-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 49fbecdc052611ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Ancient Cedars Trail,
# Difficulty: Intermediate,
# Time: 2,
# Rating: 3.07,
# Trip Time: 5,
# Elevation Gain: 175,
# Season: June-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: eafdf692052211ec9f58cf7d0294de9c,
# region: Whistler,
# Trail Title: Ancient Cedars Trail,
# Difficulty: Intermediate,
# Time: 2,
# Rating: 3.07,
# Trip Time: 5,
# Elevation Gain: 175,
# Season: June-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 36fae776053211ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Cheakamus Canyon Trail,
# Difficulty: Easy,
# Time: 3,
# Rating: 5,
# Trip Time: 9,
# Elevation Gain: 250,
# Season: April-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: a8a6eb2c053211ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Dorman Point,
# Difficulty: Easy,
# Time: 1,
# Rating: 4.67,
# Trip Time: 3,
# Elevation Gain: 105,
# Season: year-round,
# Camping: False,
# Public Transit: True,
# Dog Friendly: True
#
#
# id: fbb9f156057311ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Elfin Lakes,
# Difficulty: Intermediate,
# Time: 6,
# Rating: 4.49,
# Trip Time: 22,
# Elevation Gain: 600,
# Season: July-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 374a19b8053211ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Crooked Falls,
# Difficulty: Intermediate,
# Time: 3.5,
# Rating: 4.08,
# Trip Time: 6,
# Elevation Gain: 395,
# Season: April-November,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 37a9b9a4053211ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Demon Ridge,
# Difficulty: Difficult,
# Time: 8,
# Rating: 4,
# Trip Time: 16,
# Elevation Gain: 975,
# Season: July-September,
# Camping: False,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 49e4110c052611ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Al's Habrich Ridge Trail,
# Difficulty: Intermediate,
# Time: 5,
# Rating: 4,
# Trip Time: 7,
# Elevation Gain: 440,
# Season: July-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 49fb4020052611ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Alice Lake,
# Difficulty: Easy,
# Time: 2,
# Rating: 4,
# Trip Time: 6,
# Elevation Gain: 300,
# Season: April-November,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4af9e418052611ec9f58cf7d0294de9c,
# region: Howe Sound,
# Trail Title: Brohm Lake,
# Difficulty: Intermediate,
# Time: 5,
# Rating: 3.67,
# Trip Time: 8,
# Elevation Gain: 100,
# Season: April-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 37213304053211ec9f58cf7d0294de9c,
# region: Sunshine Coast,
# Trail Title: Cliff Gilker Park,
# Difficulty: Easy,
# Time: 1,
# Rating: 5,
# Trip Time: 2,
# Elevation Gain: 50,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4b5b2976052611ec9f58cf7d0294de9c,
# region: Sunshine Coast,
# Trail Title: Burnett Falls,
# Difficulty: Easy,
# Time: 0.5,
# Rating: 5,
# Trip Time: 1,
# Elevation Gain: 30,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbf1d0b2057311ec9f58cf7d0294de9c,
# region: Sunshine Coast,
# Trail Title: Francis Point Provincial Park,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 5,
# Trip Time: 3,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 36f53e7a053211ec9f58cf7d0294de9c,
# region: Sunshine Coast,
# Trail Title: Chapman Falls,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 1,
# Trip Time: 4,
# Elevation Gain: 40,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 49ee45f0052611ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Alexandra Bridge,
# Difficulty: Easy,
# Time: 0.5,
# Rating: 5,
# Trip Time: 2,
# Elevation Gain: 50,
# Season: March-November,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbc23c94057311ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Falls Lake,
# Difficulty: Easy,
# Time: 1,
# Rating: 5,
# Trip Time: 2,
# Elevation Gain: 52,
# Season: May-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: a8ad10c4053211ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Downes Bowl Trail,
# Difficulty: Easy,
# Time: 1,
# Rating: 4.67,
# Trip Time: 3,
# Elevation Gain: 55,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbc13cae057311ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Elk Mountain,
# Difficulty: Intermediate,
# Time: 4,
# Rating: 4.62,
# Trip Time: 7,
# Elevation Gain: 800,
# Season: June-October,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4a7962fc052611ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Bosumarne Falls,
# Difficulty: Easy,
# Time: 1,
# Rating: 4.27,
# Trip Time: 3,
# Elevation Gain: 75,
# Season: April-November,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 49d14874052611ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Abby Grind,
# Difficulty: Intermediate,
# Time: 1.5,
# Rating: 4.25,
# Trip Time: 4,
# Elevation Gain: 330,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 36ef97b8053211ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Cascade Falls,
# Difficulty: Easy,
# Time: 0.5,
# Rating: 4.22,
# Trip Time: 1,
# Elevation Gain: 40,
# Season: April-November,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbcd43c8057311ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Flood Falls,
# Difficulty: Easy,
# Time: 0.75,
# Rating: 4,
# Trip Time: 1,
# Elevation Gain: 40,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 37020560053211ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Cheam Lake Wetlands,
# Difficulty: Easy,
# Time: 1,
# Rating: 3.67,
# Trip Time: 2,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: False
#
#
# id: 370e6e7c053211ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Chilliwack Community Forest,
# Difficulty: Easy,
# Time: 1.5,
# Rating: 3.5,
# Trip Time: 3,
# Elevation Gain: 150,
# Season: Febuary-November,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4addbd4c052611ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Bridal Veil Falls,
# Difficulty: Easy,
# Time: 0.25,
# Rating: 3.25,
# Trip Time: 1,
# Elevation Gain: 50,
# Season: May-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: 4b1414be052611ec9f58cf7d0294de9c,
# region: Fraser Valley East,
# Trail Title: Browne Creek Wetlands,
# Difficulty: Easy,
# Time: 0.75,
# Rating: 0,
# Trip Time: 3,
# Elevation Gain: 152,
# Season: year-round,
# Camping: False,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fc24b09a057311ec9f58cf7d0294de9c,
# region: Ridge Meadows,
# Trail Title: Golden Ears Canyon Loop,
# Difficulty: Intermediate,
# Time: 4,
# Rating: 4.53,
# Trip Time: 12,
# Elevation Gain: 185,
# Season: April-October,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fc204424057311ec9f58cf7d0294de9c,
# region: Ridge Meadows,
# Trail Title: Golden Ears,
# Difficulty: Difficult,
# Time: 12,
# Rating: 4.48,
# Trip Time: 24,
# Elevation Gain: 1500,
# Season: July-September,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fc1b9bcc057311ec9f58cf7d0294de9c,
# region: Ridge Meadows,
# Trail Title: Gold Creek Falls,
# Difficulty: Easy,
# Time: 2,
# Rating: 4.07,
# Trip Time: 6,
# Elevation Gain: 152,
# Season: year-round,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
#
#
# id: fbf2c01c057311ec9f58cf7d0294de9c,
# region: Manning Provincial Park,
# Trail Title: Frosty Mountain,
# Difficulty: Difficult,
# Time: 8,
# Rating: 4.25,
# Trip Time: 22,
# Elevation Gain: 1160,
# Season: July-September,
# Camping: True,
# Public Transit: False,
# Dog Friendly: True
